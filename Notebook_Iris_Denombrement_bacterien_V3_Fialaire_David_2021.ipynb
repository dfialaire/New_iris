# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Jun  6 21:20:18 2020

@author: dfial
"""
# -*- coding: utf-8 -*-
from tkinter import filedialog
from tkinter import *
from tkinter import messagebox
import pickle
import os
import sys
import time
import numpy as np
import cv2
from PIL import Image
#from pylab import *
import matplotlib
from matplotlib.pyplot import *
import matplotlib.pyplot as plt
import numpy
import statistics
from itertools import chain
import imageio
import webbrowser
# ###################################################
# try:
#     # new location for sip
#     # https://www.riverbankcomputing.com/static/Docs/PyQt5/incompatibilities.html#pyqt-v5-11
#     from PyQt5 import sip
# except ImportError:
#     import sip
################################################
from PyQt5 import uic



from PyQt5.QtWidgets import QApplication 
from PyQt5.QtWidgets import QFrame 
from PyQt5.QtWidgets import QHBoxLayout
from PyQt5.QtWidgets import QGroupBox
from PyQt5.QtWidgets import QVBoxLayout 
from PyQt5.QtWidgets import QRadioButton
from PyQt5.QtWidgets import QLabel
from PyQt5.QtWidgets import QWidget
from PyQt5.QtWidgets import QPushButton
from PyQt5.QtWidgets import QSlider
from PyQt5.QtWidgets import QCheckBox
from PyQt5.QtWidgets import QSpinBox
from PyQt5.QtWidgets import QDial
from PyQt5.QtWidgets import QLCDNumber
from PyQt5.QtWidgets import QTextEdit
from PyQt5.QtWidgets import QAbstractScrollArea

from PyQt5.QtGui import QImage 
from PyQt5.QtGui import QPainter 
from PyQt5.QtGui import QPen 
from PyQt5.QtGui import QFont
from PyQt5.QtGui import QPixmap
from PyQt5.QtGui import QIcon
from PyQt5.QtGui import QDesktopServices
from PyQt5.QtGui import QPalette
from PyQt5.QtGui import QBrush
from PyQt5.QtGui import QColor
from PyQt5.QtGui import QCursor

from PyQt5.QtCore import QTimer 
from PyQt5.QtCore import QPoint 
from PyQt5.QtCore import Qt
from PyQt5.QtCore import QUrl
from PyQt5.QtCore import QRect
from PyQt5.QtCore import QSize
from PyQt5.QtCore import QCoreApplication
from PyQt5.QtCore import QMetaObject

class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.setEnabled(True)
        Form.resize(1361, 700)
        icon = QIcon()
        icon.addPixmap(QPixmap("Finn/IconeIrisV2.ico"), QIcon.Normal, QIcon.Off)
        icon.addPixmap(QPixmap("Finn/IconeIrisV2.ico"), QIcon.Normal, QIcon.On)
        icon.addPixmap(QPixmap("Finn/IconeIrisV2.ico"), QIcon.Disabled, QIcon.Off)
        icon.addPixmap(QPixmap("Finn/IconeIrisV2.ico"), QIcon.Disabled, QIcon.On)
        icon.addPixmap(QPixmap("Finn/IconeIrisV2.ico"), QIcon.Active, QIcon.Off)
        icon.addPixmap(QPixmap("Finn/IconeIrisV2.ico"), QIcon.Active, QIcon.On)
        icon.addPixmap(QPixmap("Finn/IconeIrisV2.ico"), QIcon.Selected, QIcon.Off)
        icon.addPixmap(QPixmap("Finn/IconeIrisV2.ico"), QIcon.Selected, QIcon.On)
        Form.setWindowIcon(icon)

        self.image_label = QLabel(Form)
        self.image_label.setGeometry(QRect(10, 50, 640, 480))
        self.image_label.setStyleSheet("background-color: rgb(170, 170, 255);")
        self.image_label.setObjectName("image_label")
        self.control_Quit = QPushButton(Form)
        self.control_Quit.setGeometry(QRect(1180, 10, 100, 35))
        palette = QPalette()
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.WindowText, brush)
        brush = QBrush(QColor(255, 97, 83))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Mid, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.BrightText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ButtonText, brush)
        brush = QBrush(QColor(255, 97, 83))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Base, brush)
        brush = QBrush(QColor(255, 97, 83))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Shadow, brush)
        brush = QBrush(QColor(247, 176, 162))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ToolTipText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.WindowText, brush)
        brush = QBrush(QColor(255, 97, 83))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Mid, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.BrightText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ButtonText, brush)
        brush = QBrush(QColor(255, 97, 83))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Base, brush)
        brush = QBrush(QColor(255, 97, 83))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Shadow, brush)
        brush = QBrush(QColor(247, 176, 162))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ToolTipText, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.WindowText, brush)
        brush = QBrush(QColor(255, 97, 83))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Mid, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.BrightText, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ButtonText, brush)
        brush = QBrush(QColor(255, 97, 83))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Base, brush)
        brush = QBrush(QColor(255, 97, 83))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Shadow, brush)
        brush = QBrush(QColor(240, 98, 69))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ToolTipText, brush)
        self.control_Quit.setPalette(palette)
        self.control_Quit.setStyleSheet("background-color: rgb(255, 97, 83);\n"
"font: 87 14pt \"Arial Black\";")
        self.control_Quit.setObjectName("control_Quit")
        self.groupBox = QGroupBox(Form)
        self.groupBox.setGeometry(QRect(660, 50, 621, 241))
        self.groupBox.setStyleSheet("background-color: rgb(239, 197, 255);")
        self.groupBox.setFlat(True)
        self.groupBox.setCheckable(False)
        self.groupBox.setObjectName("groupBox")
        self.radioButton_Webcam = QRadioButton(self.groupBox)
        self.radioButton_Webcam.setGeometry(QRect(150, 20, 101, 31))
        self.radioButton_Webcam.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(85, 170, 255);")
        self.radioButton_Webcam.setCheckable(True)
        self.radioButton_Webcam.setChecked(False)
        self.radioButton_Webcam.setObjectName("radioButton_Webcam")
        self.radioButton_Capture = QRadioButton(self.groupBox)
        self.radioButton_Capture.setEnabled(True)
        self.radioButton_Capture.setGeometry(QRect(300, 20, 101, 31))
        self.radioButton_Capture.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(170, 255, 127);")
        self.radioButton_Capture.setObjectName("radioButton_Capture")
        self.radioButton_Tutos = QRadioButton(self.groupBox)
        self.radioButton_Tutos.setGeometry(QRect(450, 20, 82, 31))
        self.radioButton_Tutos.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(255, 170, 0);")
        self.radioButton_Tutos.setObjectName("radioButton_Tutos")
        self.radioButton_Intro = QRadioButton(self.groupBox)
        self.radioButton_Intro.setGeometry(QRect(20, 20, 82, 31))
        self.radioButton_Intro.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(222, 157, 213);")
        self.radioButton_Intro.setChecked(True)
        self.radioButton_Intro.setObjectName("radioButton_Intro")
        self.label_Fonce = QLabel(self.groupBox)
        self.label_Fonce.setGeometry(QRect(20, 180, 81, 20))
        self.label_Fonce.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(255, 255, 255, 255), stop:1 rgba(0, 0, 0, 255));\n"
"font: 87 8pt \"Arial Black\";\n"
"border-color: rgb(0, 0, 0);")
        self.label_Fonce.setObjectName("label_Fonce")
        self.horizontalSlider_Clair = QSlider(self.groupBox)
        self.horizontalSlider_Clair.setGeometry(QRect(20, 140, 261, 22))
        self.horizontalSlider_Clair.setMinimumSize(QSize(261, 22))
        self.horizontalSlider_Clair.setMaximumSize(QSize(261, 22))
        self.horizontalSlider_Clair.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(153, 153, 93, 255), stop:1 rgba(255, 255, 255, 255));\n"
"color: rgb(0, 0, 0);")
        self.horizontalSlider_Clair.setMaximum(25)
        self.horizontalSlider_Clair.setPageStep(1)
        self.horizontalSlider_Clair.setOrientation(Qt.Horizontal)
        self.horizontalSlider_Clair.setObjectName("horizontalSlider_Clair")
        self.label_Clair = QLabel(self.groupBox)
        self.label_Clair.setGeometry(QRect(20, 120, 61, 21))
        self.label_Clair.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(153, 153, 93, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 87 8pt \"Arial Black\";\n"
"border-color: rgb(0, 0, 0);")
        self.label_Clair.setObjectName("label_Clair")
        self.horizontalSlider_Sombre = QSlider(self.groupBox)
        self.horizontalSlider_Sombre.setGeometry(QRect(20, 200, 261, 22))
        self.horizontalSlider_Sombre.setMinimumSize(QSize(261, 22))
        self.horizontalSlider_Sombre.setMaximumSize(QSize(261, 22))
        self.horizontalSlider_Sombre.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(255, 255, 255, 255), stop:1 rgba(0, 0, 0, 255));\n"
"color: rgb(0, 0, 0);")
        self.horizontalSlider_Sombre.setMaximum(25)
        self.horizontalSlider_Sombre.setPageStep(1)
        self.horizontalSlider_Sombre.setOrientation(Qt.Horizontal)
        self.horizontalSlider_Sombre.setObjectName("horizontalSlider_Sombre")
        self.pushButton_Grand = QPushButton(self.groupBox)
        self.pushButton_Grand.setGeometry(QRect(140, 70, 121, 31))
        self.pushButton_Grand.setStyleSheet("font: 87 17pt \"Arial Black\";")
        self.pushButton_Grand.setObjectName("pushButton_Grand")
        self.pushButton_Petit = QPushButton(self.groupBox)
        self.pushButton_Petit.setGeometry(QRect(20, 70, 111, 31))
        self.pushButton_Petit.setStyleSheet("font: 87 17pt \"Arial Black\";\n"
"font: 16pt \"MS Shell Dlg 2\";")
        self.pushButton_Petit.setObjectName("pushButton_Petit")
        self.checkBox_Zoom = QCheckBox(self.groupBox)
        self.checkBox_Zoom.setGeometry(QRect(310, 70, 101, 41))
        self.checkBox_Zoom.setStyleSheet("font: 18pt \"Lucida Handwriting\";\n"
"background-color: qradialgradient(spread:pad, cx:0.227273, cy:0.335, radius:0.781, fx:0, fy:0.295455, stop:0 rgba(113, 0, 85, 255), stop:1 rgba(255, 255, 255, 255));\n"
"gridline-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.077, fx:0.5, fy:0.5, stop:0 rgba(0, 169, 255, 147), stop:0.497326 rgba(0, 0, 0, 147), stop:1 rgba(0, 169, 255, 147));")
        self.checkBox_Zoom.setObjectName("checkBox_Zoom")
        self.spinBox_3 = QSpinBox(self.groupBox)
        self.spinBox_3.setGeometry(QRect(280, 140, 42, 22))
        self.spinBox_3.setObjectName("spinBox_3")
        self.spinBox_4 = QSpinBox(self.groupBox)
        self.spinBox_4.setGeometry(QRect(280, 200, 42, 22))
        self.spinBox_4.setObjectName("spinBox_4")
        self.groupBox_4 = QGroupBox(self.groupBox)
        self.groupBox_4.setGeometry(QRect(300, 130, 31, 101))
        self.groupBox_4.setTitle("")
        self.groupBox_4.setObjectName("groupBox_4")
        self.spinBox_5 = QSpinBox(self.groupBox)
        self.spinBox_5.setGeometry(QRect(530, 20, 51, 31))
        self.spinBox_5.setStyleSheet("background-color: rgb(255, 170, 0);")
        self.spinBox_5.setProperty("value", 1)
        self.spinBox_5.setObjectName("spinBox_5")
        self.groupBox_5 = QGroupBox(self.groupBox)
        self.groupBox_5.setGeometry(QRect(560, 10, 31, 51))
        self.groupBox_5.setTitle("")
        self.groupBox_5.setObjectName("groupBox_5")
        self.horizontalSlider_Tutos = QSlider(self.groupBox)
        self.horizontalSlider_Tutos.setEnabled(False)
        self.horizontalSlider_Tutos.setGeometry(QRect(450, 50, 160, 22))
        self.horizontalSlider_Tutos.setStyleSheet("background-color: rgb(226, 151, 0);")
        self.horizontalSlider_Tutos.setMinimum(1)
        self.horizontalSlider_Tutos.setMaximum(10)
        self.horizontalSlider_Tutos.setOrientation(Qt.Horizontal)
        self.horizontalSlider_Tutos.setObjectName("horizontalSlider_Tutos")
        self.groupBox_6 = QGroupBox(self.groupBox)
        self.groupBox_6.setGeometry(QRect(350, 130, 241, 80))
        font = QFont()
        font.setFamily("MS Shell Dlg 2")
        font.setPointSize(8)
        font.setBold(True)
        font.setItalic(False)
        font.setUnderline(True)
        font.setWeight(75)
        self.groupBox_6.setFont(font)
        self.groupBox_6.setStyleSheet("background-color: rgb(239, 197, 255);\n"
"background-color: rgb(246, 210, 255);")
        self.groupBox_6.setFlat(True)
        self.groupBox_6.setObjectName("groupBox_6")
        self.radioButton_Coul_Col = QRadioButton(self.groupBox_6)
        self.radioButton_Coul_Col.setGeometry(QRect(40, 20, 171, 31))
        self.radioButton_Coul_Col.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
";")
        self.radioButton_Coul_Col.setChecked(True)
        self.radioButton_Coul_Col.setObjectName("radioButton_Coul_Col")
        self.radioButton_Coul_Mil = QRadioButton(self.groupBox_6)
        self.radioButton_Coul_Mil.setGeometry(QRect(40, 60, 161, 17))
        self.radioButton_Coul_Mil.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"")
        self.radioButton_Coul_Mil.setObjectName("radioButton_Coul_Mil")
        self.groupBox_2 = QGroupBox(Form)
        self.groupBox_2.setGeometry(QRect(660, 310, 301, 61))
        self.groupBox_2.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-color: rgb(0, 0, 0);")
        self.groupBox_2.setFlat(True)
        self.groupBox_2.setCheckable(False)
        self.groupBox_2.setObjectName("groupBox_2")
        self.radioButton_Vert = QRadioButton(self.groupBox_2)
        self.radioButton_Vert.setGeometry(QRect(100, 20, 71, 31))
        self.radioButton_Vert.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(0, 85, 0);\n"
"font: 87 14pt \"Arial Black\";")
        self.radioButton_Vert.setCheckable(True)
        self.radioButton_Vert.setChecked(False)
        self.radioButton_Vert.setObjectName("radioButton_Vert")
        self.radioButton_Rouge = QRadioButton(self.groupBox_2)
        self.radioButton_Rouge.setGeometry(QRect(190, 20, 91, 31))
        self.radioButton_Rouge.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"font: 87 14pt \"Arial Black\";\n"
"color: rgb(255, 0, 0);")
        self.radioButton_Rouge.setObjectName("radioButton_Rouge")
        self.radioButton_Bleu = QRadioButton(self.groupBox_2)
        self.radioButton_Bleu.setGeometry(QRect(20, 20, 71, 31))
        self.radioButton_Bleu.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(0, 0, 127);\n"
"font: 87 14pt \"Arial Black\";")
        self.radioButton_Bleu.setChecked(True)
        self.radioButton_Bleu.setObjectName("radioButton_Bleu")
        self.groupBox_3 = QGroupBox(Form)
        self.groupBox_3.setGeometry(QRect(660, 380, 301, 141))
        self.groupBox_3.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.groupBox_3.setObjectName("groupBox_3")
        self.horizontalSlider_Inf = QSlider(self.groupBox_3)
        self.horizontalSlider_Inf.setGeometry(QRect(60, 40, 181, 22))
        self.horizontalSlider_Inf.setMaximum(11)
        self.horizontalSlider_Inf.setOrientation(Qt.Horizontal)
        self.horizontalSlider_Inf.setObjectName("horizontalSlider_Inf")
        self.horizontalSlider_Sup = QSlider(self.groupBox_3)
        self.horizontalSlider_Sup.setEnabled(True)
        self.horizontalSlider_Sup.setGeometry(QRect(60, 70, 181, 41))
        self.horizontalSlider_Sup.setMinimum(0)
        self.horizontalSlider_Sup.setMaximum(11)
        self.horizontalSlider_Sup.setProperty("value", 11)
        self.horizontalSlider_Sup.setOrientation(Qt.Horizontal)
        self.horizontalSlider_Sup.setObjectName("horizontalSlider_Sup")
        self.label = QLabel(self.groupBox_3)
        self.label.setGeometry(QRect(0, 0, 51, 21))
        self.label.setObjectName("label")
        self.label_2 = QLabel(self.groupBox_3)
        self.label_2.setGeometry(QRect(250, 90, 51, 21))
        self.label_2.setObjectName("label_2")
        self.label_3 = QLabel(self.groupBox_3)
        self.label_3.setGeometry(QRect(10, 20, 51, 21))
        self.label_3.setObjectName("label_3")
        self.label_4 = QLabel(self.groupBox_3)
        self.label_4.setGeometry(QRect(250, 110, 51, 21))
        self.label_4.setObjectName("label_4")
        self.spinBox = QSpinBox(self.groupBox_3)
        self.spinBox.setGeometry(QRect(10, 40, 71, 22))
        self.spinBox.setObjectName("spinBox")
        self.spinBox_2 = QSpinBox(self.groupBox_3)
        self.spinBox_2.setGeometry(QRect(250, 70, 71, 22))
        self.spinBox_2.setStyleSheet("")
        self.spinBox_2.setProperty("value", 11)
        self.spinBox_2.setObjectName("spinBox_2")
        self.label.raise_()
        self.label_2.raise_()
        self.label_3.raise_()
        self.label_4.raise_()
        self.spinBox.raise_()
        self.horizontalSlider_Sup.raise_()
        self.spinBox_2.raise_()
        self.horizontalSlider_Inf.raise_()
        self.groupBox_7 = QGroupBox(Form)
        self.groupBox_7.setGeometry(QRect(970, 300, 311, 221))
        self.groupBox_7.setStyleSheet("font: 14pt \"Viner Hand ITC\";\n"
"background-color: rgb(170, 255, 127);")
        self.groupBox_7.setFlat(True)
        self.groupBox_7.setObjectName("groupBox_7")
        self.groupBox_8 = QGroupBox(self.groupBox_7)
        self.groupBox_8.setGeometry(QRect(10, 30, 271, 91))
        self.groupBox_8.setStyleSheet("font: 10pt \"Arial\";\n"
"background-color: rgb(78, 150, 70);")
        self.groupBox_8.setObjectName("groupBox_8")
        self.radioButton_Aire_Off = QRadioButton(self.groupBox_8)
        self.radioButton_Aire_Off.setGeometry(QRect(30, 60, 61, 17))
        self.radioButton_Aire_Off.setStyleSheet("font: 87 12pt \"Arial Black\";")
        self.radioButton_Aire_Off.setChecked(True)
        self.radioButton_Aire_Off.setObjectName("radioButton_Aire_Off")
        self.radioButton_Aire_On = QRadioButton(self.groupBox_8)
        self.radioButton_Aire_On.setGeometry(QRect(30, 20, 61, 17))
        self.radioButton_Aire_On.setStyleSheet("font: 87 12pt \"Arial Black\";")
        self.radioButton_Aire_On.setObjectName("radioButton_Aire_On")
        self.label_5 = QLabel(self.groupBox_8)
        self.label_5.setGeometry(QRect(10, 40, 111, 16))
        self.label_5.setObjectName("label_5")
        self.dial = QDial(self.groupBox_8)
        self.dial.setGeometry(QRect(119, 10, 61, 71))
        self.dial.setObjectName("dial")
        self.lcdNumber = QLCDNumber(self.groupBox_8)
        self.lcdNumber.setGeometry(QRect(190, 40, 64, 23))
        self.lcdNumber.setObjectName("lcdNumber")
        self.label_6 = QLabel(self.groupBox_8)
        self.label_6.setGeometry(QRect(180, 20, 81, 16))
        self.label_6.setStyleSheet("\n"
"font: 87 8pt \"Arial Black\";")
        self.label_6.setObjectName("label_6")
        self.groupBox_9 = QGroupBox(self.groupBox_7)
        self.groupBox_9.setGeometry(QRect(90, 130, 211, 80))
        self.groupBox_9.setStyleSheet("font: 10pt \"Arial\";\n"
"background-color: rgb(185, 255, 79);\n"
"font: italic 14pt \"Perpetua\";")
        self.groupBox_9.setFlat(True)
        self.groupBox_9.setObjectName("groupBox_9")
        self.radioButton_Paq_Off = QRadioButton(self.groupBox_9)
        self.radioButton_Paq_Off.setGeometry(QRect(90, 60, 61, 17))
        self.radioButton_Paq_Off.setStyleSheet("font: 87 12pt \"Arial Black\";")
        self.radioButton_Paq_Off.setChecked(True)
        self.radioButton_Paq_Off.setObjectName("radioButton_Paq_Off")
        self.radioButton_Paq_On = QRadioButton(self.groupBox_9)
        self.radioButton_Paq_On.setGeometry(QRect(90, 30, 61, 17))
        self.radioButton_Paq_On.setStyleSheet("font: 87 12pt \"Arial Black\";")
        self.radioButton_Paq_On.setObjectName("radioButton_Paq_On")
        self.groupBox_10 = QGroupBox(Form)
        self.groupBox_10.setGeometry(QRect(10, 10, 641, 41))
        self.groupBox_10.setStyleSheet("font: 75 14pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(202, 202, 202);\n"
"text-decoration: underline;\n"
"")
        self.groupBox_10.setObjectName("groupBox_10")
        self.pushButton_Reset = QPushButton(self.groupBox_10)
        self.pushButton_Reset.setGeometry(QRect(470, 0, 171, 31))
        palette = QPalette()
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.WindowText, brush)
        brush = QBrush(QColor(225, 225, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Mid, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.BrightText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ButtonText, brush)
        brush = QBrush(QColor(225, 225, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Base, brush)
        brush = QBrush(QColor(225, 225, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Shadow, brush)
        brush = QBrush(QColor(247, 176, 162))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ToolTipText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.WindowText, brush)
        brush = QBrush(QColor(225, 225, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Mid, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.BrightText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ButtonText, brush)
        brush = QBrush(QColor(225, 225, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Base, brush)
        brush = QBrush(QColor(225, 225, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Shadow, brush)
        brush = QBrush(QColor(247, 176, 162))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ToolTipText, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.WindowText, brush)
        brush = QBrush(QColor(225, 225, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Mid, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.BrightText, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ButtonText, brush)
        brush = QBrush(QColor(225, 225, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Base, brush)
        brush = QBrush(QColor(225, 225, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Shadow, brush)
        brush = QBrush(QColor(240, 98, 69))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ToolTipText, brush)
        self.pushButton_Reset.setPalette(palette)
        self.pushButton_Reset.setStyleSheet("background-color: rgb(225, 225, 0);\n"
"font: 87 12pt \"Arial Black\";")
        self.pushButton_Reset.setObjectName("pushButton_Reset")
        self.pushButton_Charge = QPushButton(self.groupBox_10)
        self.pushButton_Charge.setGeometry(QRect(210, 0, 91, 31))
        palette = QPalette()
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.WindowText, brush)
        brush = QBrush(QColor(103, 202, 131))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Mid, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.BrightText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ButtonText, brush)
        brush = QBrush(QColor(103, 202, 131))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Base, brush)
        brush = QBrush(QColor(103, 202, 131))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Shadow, brush)
        brush = QBrush(QColor(247, 176, 162))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ToolTipText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.WindowText, brush)
        brush = QBrush(QColor(103, 202, 131))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Mid, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.BrightText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ButtonText, brush)
        brush = QBrush(QColor(103, 202, 131))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Base, brush)
        brush = QBrush(QColor(103, 202, 131))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Shadow, brush)
        brush = QBrush(QColor(247, 176, 162))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ToolTipText, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.WindowText, brush)
        brush = QBrush(QColor(103, 202, 131))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Mid, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.BrightText, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ButtonText, brush)
        brush = QBrush(QColor(103, 202, 131))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Base, brush)
        brush = QBrush(QColor(103, 202, 131))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Shadow, brush)
        brush = QBrush(QColor(240, 98, 69))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ToolTipText, brush)
        self.pushButton_Charge.setPalette(palette)
        self.pushButton_Charge.setStyleSheet("background-color: rgb(103, 202, 131);\n"
"font: 87 12pt \"Arial Black\";")
        self.pushButton_Charge.setObjectName("pushButton_Charge")
        self.pushButton_Sauve = QPushButton(self.groupBox_10)
        self.pushButton_Sauve.setGeometry(QRect(320, 0, 141, 31))
        palette = QPalette()
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.WindowText, brush)
        brush = QBrush(QColor(255, 126, 94))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Mid, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.BrightText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ButtonText, brush)
        brush = QBrush(QColor(255, 126, 94))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Base, brush)
        brush = QBrush(QColor(255, 126, 94))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.Shadow, brush)
        brush = QBrush(QColor(247, 176, 162))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Active, QPalette.ToolTipText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.WindowText, brush)
        brush = QBrush(QColor(255, 126, 94))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Mid, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.BrightText, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ButtonText, brush)
        brush = QBrush(QColor(255, 126, 94))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Base, brush)
        brush = QBrush(QColor(255, 126, 94))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.Shadow, brush)
        brush = QBrush(QColor(247, 176, 162))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Inactive, QPalette.ToolTipText, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.WindowText, brush)
        brush = QBrush(QColor(255, 126, 94))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Button, brush)
        brush = QBrush(QColor(255, 192, 179))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Light, brush)
        brush = QBrush(QColor(247, 145, 124))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Midlight, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Dark, brush)
        brush = QBrush(QColor(160, 65, 46))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Mid, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Text, brush)
        brush = QBrush(QColor(255, 255, 255))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.BrightText, brush)
        brush = QBrush(QColor(120, 49, 34))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ButtonText, brush)
        brush = QBrush(QColor(255, 126, 94))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Base, brush)
        brush = QBrush(QColor(255, 126, 94))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Window, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.Shadow, brush)
        brush = QBrush(QColor(240, 98, 69))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.AlternateBase, brush)
        brush = QBrush(QColor(255, 255, 220))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ToolTipBase, brush)
        brush = QBrush(QColor(0, 0, 0))
        brush.setStyle(Qt.SolidPattern)
        palette.setBrush(QPalette.Disabled, QPalette.ToolTipText, brush)
        self.pushButton_Sauve.setPalette(palette)
        self.pushButton_Sauve.setStyleSheet("background-color: rgb(255, 126, 94);\n"
"font: 87 12pt \"Arial Black\";")
        self.pushButton_Sauve.setObjectName("pushButton_Sauve")
        self.label_7 = QLabel(Form)
        self.label_7.setEnabled(False)
        self.label_7.setGeometry(QRect(20, 60, 371, 21))
        self.label_7.setStyleSheet("font: 75 16pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 255, 0);")
        self.label_7.setWordWrap(False)
        self.label_7.setObjectName("label_7")
        self.label_8 = QLabel(Form)
        self.label_8.setEnabled(False)
        self.label_8.setGeometry(QRect(480, 60, 161, 20))
        self.label_8.setStyleSheet("font: 75 16pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 255, 0);")
        self.label_8.setWordWrap(False)
        self.label_8.setObjectName("label_8")
        self.label_9 = QLabel(Form)
        self.label_9.setEnabled(False)
        self.label_9.setGeometry(QRect(480, 90, 161, 20))
        self.label_9.setStyleSheet("font: 75 16pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 255, 0);")
        self.label_9.setWordWrap(False)
        self.label_9.setObjectName("label_9")
        self.label_10 = QLabel(Form)
        self.label_10.setEnabled(False)
        self.label_10.setGeometry(QRect(480, 130, 161, 20))
        self.label_10.setStyleSheet("font: 75 16pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 255, 0);")
        self.label_10.setWordWrap(False)
        self.label_10.setObjectName("label_10")
        self.label_11 = QLabel(Form)
        self.label_11.setEnabled(False)
        self.label_11.setGeometry(QRect(510, 230, 101, 20))
        self.label_11.setStyleSheet("font: 75 16pt \"MS Shell Dlg 2\";\n"
"color: rgb(0, 170, 255);")
        self.label_11.setWordWrap(False)
        self.label_11.setObjectName("label_11")
        self.label_12 = QLabel(Form)
        self.label_12.setEnabled(False)
        self.label_12.setGeometry(QRect(510, 250, 101, 20))
        self.label_12.setStyleSheet("font: 75 16pt \"MS Shell Dlg 2\";\n"
"color: rgb(0, 170, 255);")
        self.label_12.setWordWrap(False)
        self.label_12.setObjectName("label_12")
        self.textEdit = QTextEdit(Form)
        self.textEdit.setEnabled(True)
        self.textEdit.setGeometry(QRect(10, 420, 171, 101))
        self.textEdit.setStyleSheet("background-color: rgb(0, 0, 0);\n"
"border-color: rgb(0, 0, 0);\n"
"color: rgb(255, 0, 0);\n"
"font: 75 10pt \"MS Shell Dlg 2\";")
        self.textEdit.setLineWidth(0)
        self.textEdit.setHorizontalScrollBarPolicy(Qt.ScrollBarAlwaysOff)
        self.textEdit.setSizeAdjustPolicy(QAbstractScrollArea.AdjustToContents)
        self.textEdit.setReadOnly(True)
        self.textEdit.setObjectName("textEdit")
        self.label_13 = QLabel(Form)
        self.label_13.setEnabled(False)
        self.label_13.setGeometry(QRect(20, 90, 341, 21))
        self.label_13.setStyleSheet("font: 75 16pt \"MS Shell Dlg 2\";\n"
"font: 87 13pt \"Arial Black\";\n"
"color: rgb(255, 0, 0);")
        self.label_13.setWordWrap(False)
        self.label_13.setObjectName("label_13")
        self.label_14 = QLabel(Form)
        self.label_14.setEnabled(False)
        self.label_14.setGeometry(QRect(10, 360, 181, 21))
        self.label_14.setStyleSheet("\n"
"font: 87 10pt \"Arial\";\n"
"color: rgb(255, 0, 0);")
        self.label_14.setWordWrap(False)
        self.label_14.setObjectName("label_14")
        self.label_15 = QLabel(Form)
        self.label_15.setEnabled(False)
        self.label_15.setGeometry(QRect(10, 380, 181, 21))
        self.label_15.setStyleSheet("\n"
"font: 87 10pt \"Arial\";\n"
"color: rgb(255, 0, 0);")
        self.label_15.setWordWrap(False)
        self.label_15.setObjectName("label_15")
        self.label_16 = QLabel(Form)
        self.label_16.setEnabled(False)
        self.label_16.setGeometry(QRect(10, 400, 231, 21))
        self.label_16.setStyleSheet("\n"
"font: 87 10pt \"Arial\";\n"
"color: rgb(255, 0, 0);")
        self.label_16.setWordWrap(False)
        self.label_16.setObjectName("label_16")
        self.checkBox_TraitOff = QCheckBox(Form)
        self.checkBox_TraitOff.setGeometry(QRect(670, 10, 151, 31))
        self.checkBox_TraitOff.setStyleSheet("color: rgb(0, 0, 0);\n"
"background-color: rgb(255, 255, 255);\n"
"font: 75 italic 14pt \"Arial\";")
        self.checkBox_TraitOff.setObjectName("checkBox_TraitOff")
        self.Alert = QLabel(Form)
        self.Alert.setEnabled(False)
        self.Alert.setGeometry(QRect(250, 440, 201, 21))
        self.Alert.setStyleSheet("\n"
"font: 87 18pt \"Arial Black\";\n"
"color: rgb(255, 0, 0);")
        self.Alert.setWordWrap(False)
        self.Alert.setObjectName("Alert")
        self.Suggestions = QTextEdit(Form)
        self.Suggestions.setGeometry(QRect(10, 570, 641, 121))
        self.Suggestions.setStyleSheet("border-color: rgb(255, 255, 255);")
        self.Suggestions.setSizeAdjustPolicy(QAbstractScrollArea.AdjustToContents)
        self.Suggestions.setObjectName("Suggestions")
        self.Titre_Suggestions = QTextEdit(Form)
        self.Titre_Suggestions.setGeometry(QRect(10, 530, 641, 41))
        self.Titre_Suggestions.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"border-color: rgb(255, 255, 255);\n"
"text-decoration: underline;")
        self.Titre_Suggestions.setSizeAdjustPolicy(QAbstractScrollArea.AdjustToContents)
        self.Titre_Suggestions.setObjectName("Titre_Suggestions")
        self.Suggestions_2 = QTextEdit(Form)
        self.Suggestions_2.setGeometry(QRect(660, 570, 621, 121))
        self.Suggestions_2.setStyleSheet("border-color: rgb(255, 255, 255);")
        self.Suggestions_2.setSizeAdjustPolicy(QAbstractScrollArea.AdjustToContents)
        self.Suggestions_2.setObjectName("Suggestions_2")
        self.pushButton_Page_iris = QPushButton(Form)
        self.pushButton_Page_iris.setGeometry(QRect(1080, 530, 201, 31))
        self.pushButton_Page_iris.setStyleSheet("font: 87 17pt \"Arial Black\";\n"
"color: rgb(0, 0, 0);\n"
"background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:0.989, y2:0.9375, stop:0 rgba(255, 255, 127, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 16pt \"MS Shell Dlg 2\";")
        self.pushButton_Page_iris.setObjectName("pushButton_Page_iris")

        self.retranslateUi(Form)
        self.horizontalSlider_Inf.valueChanged['int'].connect(self.spinBox.setValue)
        self.horizontalSlider_Sup.valueChanged['int'].connect(self.spinBox_2.setValue)
        self.horizontalSlider_Clair.valueChanged['int'].connect(self.spinBox_3.setValue)
        self.horizontalSlider_Sombre.valueChanged['int'].connect(self.spinBox_4.setValue)
        self.horizontalSlider_Tutos.valueChanged['int'].connect(self.spinBox_5.setValue)
        self.radioButton_Tutos.toggled['bool'].connect(self.horizontalSlider_Tutos.setEnabled)
        self.radioButton_Intro.toggled['bool'].connect(self.horizontalSlider_Tutos.setHidden)
        self.radioButton_Webcam.toggled['bool'].connect(self.horizontalSlider_Tutos.setHidden)
        self.radioButton_Capture.toggled['bool'].connect(self.horizontalSlider_Tutos.setHidden)
        self.dial.valueChanged['int'].connect(self.lcdNumber.display)
        self.radioButton_Tutos.toggled['bool'].connect(self.label_7.setVisible)
        self.radioButton_Webcam.toggled['bool'].connect(self.label_7.setVisible)
        self.radioButton_Capture.toggled['bool'].connect(self.label_7.setVisible)
        self.radioButton_Webcam.toggled['bool'].connect(self.label_8.setVisible)
        self.radioButton_Capture.toggled['bool'].connect(self.label_8.setVisible)
        self.radioButton_Tutos.toggled['bool'].connect(self.label_8.setVisible)
        self.radioButton_Webcam.toggled['bool'].connect(self.label_9.setVisible)
        self.radioButton_Capture.toggled['bool'].connect(self.label_9.setVisible)
        self.radioButton_Tutos.toggled['bool'].connect(self.label_9.setVisible)
        self.radioButton_Webcam.toggled['bool'].connect(self.label_10.setVisible)
        self.radioButton_Capture.toggled['bool'].connect(self.label_10.setVisible)
        self.radioButton_Tutos.toggled['bool'].connect(self.label_10.setVisible)
        self.radioButton_Webcam.toggled['bool'].connect(self.label_11.setVisible)
        self.radioButton_Capture.toggled['bool'].connect(self.label_11.setVisible)
        self.radioButton_Tutos.toggled['bool'].connect(self.label_11.setVisible)
        self.radioButton_Webcam.toggled['bool'].connect(self.label_12.setVisible)
        self.radioButton_Capture.toggled['bool'].connect(self.label_12.setVisible)
        self.radioButton_Tutos.toggled['bool'].connect(self.label_12.setVisible)
        self.checkBox_TraitOff.toggled['bool'].connect(self.Alert.setVisible)
        QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "\" Iris \" : Dénombrement direct de colonies (David Fialaire _ Juillet 2020 _ Version 2.0)"))
        self.image_label.setText(_translate("Form", "TextLabel"))
        self.control_Quit.setText(_translate("Form", "Quitter"))
        self.groupBox.setTitle(_translate("Form", "Visuel sur l\'Iris"))
        self.radioButton_Webcam.setText(_translate("Form", "Webcam"))
        self.radioButton_Capture.setText(_translate("Form", "Capture"))
        self.radioButton_Tutos.setText(_translate("Form", "Tutos"))
        self.radioButton_Intro.setText(_translate("Form", "Intro"))
        self.label_Fonce.setText(_translate("Form", "  + Foncé"))
        self.label_Clair.setText(_translate("Form", "  + Clair"))
        self.pushButton_Grand.setText(_translate("Form", "+ Grand"))
        self.pushButton_Petit.setText(_translate("Form", "+ Petit"))
        self.checkBox_Zoom.setText(_translate("Form", "Zoom"))
        self.groupBox_6.setTitle(_translate("Form", " Calibration sur .."))
        self.radioButton_Coul_Col.setText(_translate("Form", "La couleur d\'une colonie"))
        self.radioButton_Coul_Mil.setText(_translate("Form", "La couleur du milieu"))
        self.groupBox_2.setTitle(_translate("Form", "Couleurs de Contour de colonies"))
        self.radioButton_Vert.setText(_translate("Form", "Vert"))
        self.radioButton_Rouge.setText(_translate("Form", "Rouge"))
        self.radioButton_Bleu.setText(_translate("Form", "Bleu"))
        self.groupBox_3.setTitle(_translate("Form", "                                 Fonction de la Taille"))
        self.label.setText(_translate("Form", "   Diamètre "))
        self.label_2.setText(_translate("Form", " Diamètre "))
        self.label_3.setText(_translate("Form", "inférieur"))
        self.label_4.setText(_translate("Form", "supérieur"))
        self.spinBox.setWhatsThis(_translate("Form", "<html><head/><body><p align=\"center\"><br/></p></body></html>"))
        self.groupBox_7.setTitle(_translate("Form", "Résolution des paquets de colonies :"))
        self.groupBox_8.setTitle(_translate("Form", "                    Méthode via l\'aire"))
        self.radioButton_Aire_Off.setText(_translate("Form", "OFF"))
        self.radioButton_Aire_On.setText(_translate("Form", "ON"))
        self.label_5.setText(_translate("Form", "Affichage de l\'Aire"))
        self.label_6.setText(_translate("Form", "Aire imposée"))
        self.groupBox_9.setTitle(_translate("Form", "              Algorythme de Paquets"))
        self.radioButton_Paq_Off.setText(_translate("Form", "OFF"))
        self.radioButton_Paq_On.setText(_translate("Form", "ON"))
        self.groupBox_10.setTitle(_translate("Form", "Données Paramètres :"))
        self.pushButton_Reset.setText(_translate("Form", "Réinitialisation"))
        self.pushButton_Charge.setText(_translate("Form", "Charger"))
        self.pushButton_Sauve.setText(_translate("Form", "Sauvegarder"))
        self.label_7.setText(_translate("Form", "TextLabel"))
        self.label_8.setText(_translate("Form", "TextLabel"))
        self.label_9.setText(_translate("Form", "TextLabel"))
        self.label_10.setText(_translate("Form", "TextLabel"))
        self.label_11.setText(_translate("Form", "TextLabel"))
        self.label_12.setText(_translate("Form", "TextLabel"))
        self.label_13.setText(_translate("Form", "TextLabel"))
        self.label_14.setText(_translate("Form", "TextLabel"))
        self.label_15.setText(_translate("Form", "TextLabel"))
        self.label_16.setText(_translate("Form", "TextLabel"))
        self.checkBox_TraitOff.setText(_translate("Form", "Traitement Off"))
        self.Alert.setText(_translate("Form", "Traitement Off"))
        self.pushButton_Page_iris.setText(_translate("Form", "Page internet \'Iris\'"))
###################################################
class MyForm(QWidget):
    def __init__(self):
        super().__init__()
        self.ui = Ui_Form()
        self.ui.setupUi(self)
        #self.showFullScreen()
        self.showMaximized()
        ############################################
        self.fond()
        self.ui.Suggestions_2.hide()
        self.ui.Suggestions.clear()
        self.ui.Titre_Suggestions.clear()
        self.ui.Titre_Suggestions.setFontFamily("Arial Black")
        self.ui.Titre_Suggestions.setStyleSheet("color: rgb(0, 0, 255);")
        self.ui.Titre_Suggestions.setFontPointSize(14)
        Titre_Sugg_intro="Bonjour à tous, bienvenue sur Iris :"
        self.ui.Titre_Suggestions.append(Titre_Sugg_intro)
        self.ui.Suggestions.setFontPointSize(14)
        Sugg_intro="Pour bien prendre en main le logiciel, entraînez-vous.. en cliquant sur le bouton orange (Tutos).. et suivez les suggestions.\n\nDavid."
        self.ui.Suggestions.append(Sugg_intro)

        self.present=1
        self.webi=1
        self.capt=0
        self.weballum=0
        self.tuto=1
        self.Nb_List=0
        self.List_max=[]
        self.Comptage_min=400
        self.Comptage_max=0
        self.x2=382
        self.y2=284
        self.zoom2=0
        self.cl_new=0
        self.fo_new=0
        self.gamma=1
        self.new_tuto=0
        self.Tuto_allume=0
        self.inverse=0
        self.coul=(0,0,255)
        self.mode="isole"
        self.Aire_Moy=0
        self.affiche_Aire=0
        self.rayon=150
        self.Nb_sup_wh=0
        self.trait=0
        self.new_Capt=0
        ############################################
        ## Contrôle de temps pour la caméra ##
        self.timer = QTimer()
        self.cap=0
        
        self.timer.timeout.connect(self.viewCam2)
        ############################################
        ## Contrôle des boutons sur la fenetre ##
#        self.ui.control_Webcam.clicked.connect(self.ControlCam)
#        self.ui.control_Quit.clicked.connect(self.Quit)
#        self.ui.control_Capture.clicked.connect(self.Capture)
        self.ui.pushButton_Petit.clicked.connect(self.Petit)
        self.ui.pushButton_Grand.clicked.connect(self.Grand)
        
        self.ui.pushButton_Reset.clicked.connect(self.Reset)
        self.ui.pushButton_Charge.clicked.connect(self.Charge)
        self.ui.pushButton_Sauve.clicked.connect(self.Sauve)
        
        self.ui.label_7.setText(" ")
        self.ui.label_8.setText(" ")
        self.ui.label_9.setText(" ")
        self.ui.label_10.setText(" ")
        self.ui.label_11.setText(" ")
        self.ui.label_12.setText(" ")
        
        
        
        
        self.ui.horizontalSlider_Inf.valueChanged[int].connect(self.SlideValinf)
        self.ui.horizontalSlider_Sup.valueChanged[int].connect(self.SlideValsup)
        self.ui.radioButton_Aire_On.toggled.connect(self.Aire_On)
        self.ui.radioButton_Aire_Off.toggled.connect(self.Aire_Off)
        self.diam_col_inf=self.ui.spinBox.value()
        
        self.w=float(10*(pow(self.diam_col_inf,2.0627)))
        self.diam_col_sup=self.ui.spinBox_2.value()
        self.wh=float(10*(pow(self.diam_col_sup,2.0627)))
        self.Aire_col_imp=self.ui.lcdNumber.value()
        self.Ancien_Aire_col_imp=self.Aire_col_imp
        self.diam_imp=round((self.Aire_col_imp/10)**(1/2.0627))
        self.ui.radioButton_Paq_Off.toggled.connect(self.Paq_Off)
        self.ui.radioButton_Paq_On.toggled.connect(self.Paq_On)
        self.ui.radioButton_Bleu.toggled.connect(self.Bleu)
        self.ui.radioButton_Rouge.toggled.connect(self.Rouge)
        self.ui.radioButton_Vert.toggled.connect(self.Vert)
        
        self.ui.pushButton_Page_iris.clicked.connect(self.Page_iris)
        

        
        self.ui.radioButton_Coul_Mil.toggled.connect(self.Mil)
        self.ui.radioButton_Coul_Col.toggled.connect(self.Col)
        self.ui.radioButton_Intro.toggled.connect(self.Intro)
        self.ui.radioButton_Webcam.toggled.connect(self.ControlCam)
        self.ui.control_Quit.clicked.connect(self.Quit)
        self.ui.radioButton_Capture.toggled.connect(self.Capture)
        self.ui.radioButton_Tutos.toggled.connect(self.Tutos)
        self.ui.checkBox_Zoom.stateChanged.connect(self.Zoomi)
        self.ui.horizontalSlider_Tutos.valueChanged[int].connect(self.New_fTutos)
        self.cl=self.ui.horizontalSlider_Clair.value()
        self.fo=self.ui.horizontalSlider_Sombre.value()
        self.ui.horizontalSlider_Clair.valueChanged[int].connect(self.Contrast)
        self.ui.horizontalSlider_Sombre.valueChanged[int].connect(self.Contrast)
        self.ui.textEdit.setVisible(False)
        self.ui.Alert.setVisible(False)
        self.ui.label_13.setVisible(False)
        self.ui.label_14.setVisible(False)
        self.ui.label_15.setVisible(False)
        self.ui.label_16.setVisible(False)
        self.ui.checkBox_TraitOff.stateChanged.connect(self.Traioupas)
        self.ui.radioButton_Capture.setEnabled(False)
        
        ############################################
#    def mousePressEvent(self, QMouseEvent):
#        print (QMouseEvent.pos())

    def mouseReleaseEvent(self, QMouseEvent):
        cursor_position = QCursor.pos()
        cursor_array = [int(cursor_position.x()), int(cursor_position.y())]
        #print("y=",cursor_array[1])
        #print("x=",cursor_array[0])
        x22=cursor_array[1]-72
        y22=cursor_array[0]-10
        if x22>479 and y22>639: #  if x22>489 and y22>649:
            ok=2
        elif x22>479 or y22>639:  # elif x22>489 or y22>649:
            ok=2
        else:
            
            self.x2=x22
            self.y2=y22
            self.List_info_paquets=[]

        #print(cursor_array)
#########################
    def Intro(self):
        self.tuto=1
        self.ui.horizontalSlider_Tutos.setValue(1)
        self.ui.Suggestions_2.hide()
        self.ui.Suggestions.clear()
        self.ui.Titre_Suggestions.clear()
        self.ui.Titre_Suggestions.setFontFamily("Arial Black")
        self.ui.Titre_Suggestions.setStyleSheet("color: rgb(0, 0, 255);")
        self.ui.Titre_Suggestions.setFontPointSize(14)
        #self.ui.Titre_Suggestions.setTextColor("0000FF") 
        Titre_Sugg_intro="Bonjour à tous, bienvenue sur Iris :"
        self.ui.Titre_Suggestions.append(Titre_Sugg_intro)
        self.ui.Suggestions.setFontPointSize(14)
        Sugg_intro="Pour bien prendre en main le logiciel, entraînez-vous.. en cliquant sur le bouton orange (Tutos).. et suivez les suggestions.\n\nDavid."
        self.ui.Suggestions.append(Sugg_intro)
        
        self.new_Capt=0
        self.ui.radioButton_Capture.setEnabled(False)
        self.ui.textEdit.setVisible(False)
        self.ui.label_13.setVisible(False)
        self.ui.label_14.setVisible(False)
        self.ui.label_15.setVisible(False)
        self.ui.label_16.setVisible(False)
        self.ui.dial.setValue(0)
        self.Aire_col_imp=self.ui.lcdNumber.value()
        self.present=1
        self.webi=1
        self.capt=0
        self.weballum=0
        self.tuto=1
        self.Nb_List=0
        self.List_max=[]
        self.Comptage_min=400
        self.Comptage_max=0
        self.x2=284
        self.y2=382
        self.zoom2=0
        self.cl_new=0
        self.fo_new=0
        self.gamma=1
        self.new_tuto=0
        self.Tuto_allume=0
        self.inverse=0
        self.coul=(0,0,255)
        self.mode="isole"
        self.Aire_Moy=0
        self.affiche_Aire=0
        self.rayon=150
        self.Nb_sup_wh=0
        self.fond()
        self.ui.textEdit.clear()
        self.new_Capt==0
#########################
    def Page_iris(self):
        
        webbrowser.open('https://biotech-online.pagesperso-orange.fr/Soutien%20TP/Iris.htm')
        
        
#        url = QUrl("http://biotech-online.pagesperso-orange.fr/Soutien%20TP/Iris.htm")
#        QDesktopServices.openUrl(url)
        
#        QWebEngineSettings.globalSettings().setAttribute(QWebEngineSettings.PluginsEnabled,True)
#        super(window,self).__init__()
#        self.centralwid=QWidget(self)
#        self.vlayout=QVBoxLayout()
#        self.webview=QtWebEngineWidgets.QWebEngineView()
#        self.webview.setUrl(QUrl("https://youtu.be/RUH1nW4FN-0"))
#        self.vlayout.addWidget(self.webview)
#        self.centralwid.setLayout(self.vlayout)
#        self.setCentralWidget(self.centralwid)
#        self.show()
        

#########################
    def Traioupas(self):
        if self.trait==0:
            self.trait=1
        else:
            self.trait=0
#########################
    def Sauve(self):
        #print("Avant sauvegarde : inv=",inv," et inv2=",inv2, " et inverse =",inverse)
        New_list=[self.Aire_col_imp,self.webi,self.tuto,self.mode,self.diam_col_inf,self.diam_col_sup,self.inverse,self.coul,self.affiche_Aire,self.cl,self.fo,self.x2,self.y2]
        Saverootfilename=self.OuvreDialogSave()
        pickle_out=open(Saverootfilename,"wb+")
        pickle.dump(New_list,pickle_out)
        pickle_out.close()
########################
    def Charge(self):
        Openrootfilename=self.OuvreDialogOpen()
        pickle_in=open(Openrootfilename,"rb")
        After_Exist_List=pickle.load(pickle_in)
        pickle_in.close()
        listo=After_Exist_List
        self.Aire_col_imp,self.webi,self.tuto,self.mode,self.diam_col_inf,self.diam_col_sup,self.inverse,self.coul,self.affiche_Aire,self.cl,self.fo,self.x2,self.y2=listo[0],listo[1],listo[2],listo[3],listo[4],listo[5],listo[6],listo[7],listo[8],listo[9],listo[10],listo[11], listo[12]
        print(listo)
        self.ui.dial.setValue(self.Aire_col_imp)
        if self.mode=="isole":
            self.ui.radioButton_Paq_Off.setChecked(True)
            self.ui.radioButton_Paq_On.setChecked(False)
        if self.mode=="tapis":
            self.ui.radioButton_Paq_Off.setChecked(False)
            self.ui.radioButton_Paq_On.setChecked(True)
        self.ui.horizontalSlider_Inf.setValue(self.diam_col_inf)
        self.ui.horizontalSlider_Sup.setValue(self.diam_col_sup)
        if self.inverse==0:
            self.ui.radioButton_Coul_Col.setChecked(True)
            self.ui.radioButton_Coul_Mil.setChecked(False)
        if self.inverse==1:
            self.ui.radioButton_Coul_Col.setChecked(False)
            self.ui.radioButton_Coul_Mil.setChecked(True)
        if self.coul==(0,0,255):
            self.ui.radioButton_Bleu.setChecked(True)
            self.ui.radioButton_Vert.setChecked(False)
            self.ui.radioButton_Rouge.setChecked(False)
        if self.coul==(0,255,0):
            self.ui.radioButton_Bleu.setChecked(False)
            self.ui.radioButton_Vert.setChecked(True)
            self.ui.radioButton_Rouge.setChecked(False)
        if self.coul==(255,0,0):
            self.ui.radioButton_Bleu.setChecked(False)
            self.ui.radioButton_Vert.setChecked(False)
            self.ui.radioButton_Rouge.setChecked(True)
        self.ui.horizontalSlider_Clair.setValue(self.cl)
        self.ui.horizontalSlider_Sombre.setValue(self.fo)
        

########################
    def Reset(self):
        self.Aire_col_imp,self.webi,self.tuto,self.mode,self.diam_col_inf,self.diam_col_sup,self.inverse,self.coul,self.affiche_Aire,self.cl,self.fo,self.x2,self.y2, self.rayon=0,1,1,'isole',0,11,0,(0,0,255),0,0,0,284,382,150
        self.ui.dial.setValue(self.Aire_col_imp)
        if self.mode=="isole":
            self.ui.radioButton_Paq_Off.setChecked(True)
            self.ui.radioButton_Paq_On.setChecked(False)
        if self.mode=="tapis":
            self.ui.radioButton_Paq_Off.setChecked(False)
            self.ui.radioButton_Paq_On.setChecked(True)
        self.ui.horizontalSlider_Inf.setValue(self.diam_col_inf)
        self.ui.horizontalSlider_Sup.setValue(self.diam_col_sup)
        if self.inverse==0:
            self.ui.radioButton_Coul_Col.setChecked(True)
            self.ui.radioButton_Coul_Mil.setChecked(False)
        if self.inverse==1:
            self.ui.radioButton_Coul_Col.setChecked(False)
            self.ui.radioButton_Coul_Mil.setChecked(True)
        if self.coul==(0,0,255):
            self.ui.radioButton_Bleu.setChecked(True)
            self.ui.radioButton_Vert.setChecked(False)
            self.ui.radioButton_Rouge.setChecked(False)
        if self.coul==(0,255,0):
            self.ui.radioButton_Bleu.setChecked(False)
            self.ui.radioButton_Vert.setChecked(True)
            self.ui.radioButton_Rouge.setChecked(False)
        if self.coul==(255,0,0):
            self.ui.radioButton_Bleu.setChecked(False)
            self.ui.radioButton_Vert.setChecked(False)
            self.ui.radioButton_Rouge.setChecked(True)
        self.ui.horizontalSlider_Clair.setValue(self.cl)
        self.ui.horizontalSlider_Sombre.setValue(self.fo)
        self.ui.radioButton_Aire_Off.setChecked(True)
        self.ui.radioButton_Aire_On.setChecked(False)
#######################################################################
    def OuvreDialogSave(self):
        # asksaveasfilename  # askopenfilename
        root = Tk()
        root.filename =  filedialog.asksaveasfilename(initialdir = "/",title = "Select file",filetypes = (("pickle files","*.pickle"),("all files","*.*")))
        root.destroy()
        texte=root.filename+".pickle"
        return texte
    ###########################
    def OuvreDialogOpen(self):
        # asksaveasfilename  # askopenfilename
        root = Tk()
        root.filename =  filedialog.askopenfilename(initialdir = "/",title = "Select file",filetypes = (("pickle files","*.pickle"),("all files","*.*")))
        root.destroy()
        texte=root.filename
        return texte
##########################################        

###########################
    def Petit(self):
        self.rayon-=2
        pil_img=Image.open("CaptWeb.jpg") 
        self.img = numpy.array(pil_img)
        self.pe()
##########################
    def Grand(self):
        self.rayon+=2
        pil_img=Image.open("CaptWeb.jpg") 
        self.img = numpy.array(pil_img)
        self.pe()
##########################
    def SlideValinf(self):
        self.diam_col_inf=self.ui.horizontalSlider_Inf.value()
        self.w=float(10*(pow(self.diam_col_inf,2.0627)))
######################"##
    def SlideValsup(self):
        self.diam_col_sup=self.ui.horizontalSlider_Sup.value()
        self.wh=float(10*(pow(self.diam_col_sup,2.0627)))
######################"##
##############################
    def Aire_On(self):
        self.affiche_Aire=1
#########################
    def Aire_Off(self):
        self.affiche_Aire=0
#########################
    def Paq_On(self):
        self.mode="tapis"        
###########################
    def Paq_Off(self):
        self.mode="isole"        
###########################
    def Col(self):
        self.inverse=0
######################### 
    def Mil(self):
        self.inverse=1
#########################
    def Bleu(self):
        self.coul=(0,0,255)
#########################
    def Vert(self):
        self.coul=(0,255,0)
#########################
    def Rouge(self):
        self.coul=(255,0,0)
#########################

#########################        
        
    def Contrast(self):
        self.cl=self.ui.horizontalSlider_Clair.value()
        self.fo=self.ui.horizontalSlider_Sombre.value()
        if self.cl>self.cl_new:
            if self.fo==0:
                self.cl_new+=1
            else:
                self.ui.horizontalSlider_Clair.setValue(self.cl_new)
                self.fo_new=self.fo_new-1
                self.ui.horizontalSlider_Sombre.setValue(self.fo_new)
    
        if self.fo>self.fo_new:
            if self.cl==0:
                self.fo_new+=1
            else:
                
                self.ui.horizontalSlider_Sombre.setValue(self.fo_new)
                self.cl_new=self.cl_new-1
                self.ui.horizontalSlider_Clair.setValue(self.self.cl_new)
                
        if self.fo==0:
            self.gamma=float(self.cl/10)+1
        if self.cl==0:
            self.gamma=1-float(self.fo/10)
#########################
    def Quit(self):
        #app.exec()
        sys.exit(app.exec_())
#########################
#########################
    def Zoomi(self,state):
    	if (Qt.Checked == state):
    		self.zoom2=1
    	else:
    		self.zoom2=0
######################### 
    def ControlCam(self):
        if self.tuto==8:
            self.rayon=150
            self.tuto=1
#        self.ui.horizontalSlider_Tutos.setValue(1)
        self.ui.Suggestions.hide()
        self.ui.Suggestions_2.hide()
        self.ui.Titre_Suggestions.hide()
        self.new_Capt=0
        self.ui.radioButton_Capture.setEnabled(True)
        self.ui.dial.setValue(0)
        self.Aire_col_imp=self.ui.lcdNumber.value()
        self.Weballum=1
        self.present=0
        
        # if timer is stopped
        if not self.timer.isActive():
            #print("timer1=")
            # create video capture
            self.cam = cv2.VideoCapture(0)
            # start timer
            self.timer.start(20)
            # update control_bt text
            ### ui.control_bt.setText("Stop Webcam")
            self.ui.radioButton_Webcam.setText("Webcam")
        # if timer is started
        else:
            #print("timer_stop=")
            self.timer.stop()
            # release video capture
            self.cam.release()
            # update control_bt text
            ### ui.control_bt.setText("Lance Webcam")
            self.ui.radioButton_Webcam.setText("Webcam")
            #image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV) 
    #########################
    def New_fTutos(self):

        self.ui.Suggestions.clear()
        self.ui.Suggestions_2.clear()
        self.ui.Titre_Suggestions.clear()
        self.ui.Titre_Suggestions.setFontFamily("Arial Black")
        self.ui.Titre_Suggestions.setStyleSheet("color: rgb(0, 0, 255);")
        self.ui.Titre_Suggestions.setFontPointSize(14)

        #self.ui.Titre_Suggestions.setTextColor("0000FF") 
        Titre_Sugg_intro="Suggestions :"
        self.ui.Titre_Suggestions.append(Titre_Sugg_intro)
        self.ui.Suggestions.setFontPointSize(13)
        self.ui.Suggestions_2.setFontPointSize(13)

        if self.tuto==1:
            self.ui.Suggestions_2.hide()
            Sugg_Tuto="Tuto N°1 : \"Calibration colonie\"\n       -Réinitialisez (bouton jaune) ; Cliquez sur Calibration : couleur colonie.\n       -Cliquez sur une colonie bleue : le décompte est de 15 colonies.\n       -Vous pouvez changer la couleur du contour (choisir Rouge).\n                                                                                                - - - -> Tuto suivant"
        elif self.tuto==2:
            self.ui.Suggestions_2.hide()
            Sugg_Tuto="Tuto N°2 : \"Recherche en fonction de la taille\"\n       -Cliquez sur Réinitialisation ; Passez en Calibration : couleur milieu.\n       -Cliquez à cheval sur une frontière colonie/milieu : -->10 colonies.\n       -Modifiez, à volonté, les diamètres inférieur et supérieur.\n                                                                                                - - - -> Tuto suivant"
        elif self.tuto==3:
            self.ui.Suggestions_2.hide()
            Sugg_Tuto="Tuto N°3 : \"Exercice sur la taille\"\n       -Cliquez sur Réinitialisation ; Passez en Calibration : couleur milieu.\n       -Cliquez à cheval sur une frontière colonie/milieu : -->11 colonies.\n       -Isolez (diamètre) soit les petites, soit les grosses colonies à bord floutté.\n                                                                                                - - - -> Tuto suivant"
        elif self.tuto==4:
            self.ui.Suggestions_2.show()
            Sugg_Tuto="Tuto N°4 : \"les paquets de colonies\"\n       -Cliquez sur Réinitialisation ; Passez en Calibration : couleur milieu.\n       -à cheval sur une frontière de colonie, le décompte est de 2 colonies.\n       -Biensûr, c'est faux.. les colonies sont trop proches..\n       ...il y a formation de paquets par l'algorithme -->"
            Sugg_Tuto2="Résolution de paquets: 2 solutions\n       _1) \"Méthode via l'Aire\" : -Cliquez sur On dans Affichage de l'Aire,.\n       -Repérez l'aire du paquet le plus petit = Aire d'1 colonie = 63,\n       -Tournez le potentiomètre : Aire imposée à 63.\n       _2) Aire impos=0;Cliquez On dans Algorithme de paquets.  ..Tuto suivant"
            self.ui.Suggestions_2.append(Sugg_Tuto2)
            self.ui.Suggestions_2.show()
        elif self.tuto==5:
            self.ui.Suggestions_2.hide()
            Sugg_Tuto="Tuto N°5 : Exercice sur la résolution des \"paquets de colonies\"\n\n       -Refaîte comme pour le tuto précédent,\n       - Astuce: Pour cet exo, cliquez sur Réinitialisation (x,y + faciles!). ..Tuto suivant"
        elif self.tuto==6:
            self.ui.Suggestions_2.show()
            Sugg_Tuto="Tuto N°6 : \"Amélioration du contraste\" et \"Fichiers Pickle\" :\n-Faîtes Réinitialisation. Pour éviter les bords,réduisez l'iris en cliquant sur + Petit,\n-Sélectionner Calibration colonie et cliquez au centre d'une grosse colonie bleue,\n-Augmentez le curseur + clair jusqu'à l'obtiention d'un maximum de colonies,\n-Changer la couleur du contour, et vérifiez en traitement Off  ..." 
            Sugg_Tuto2="--> Réutilisation de la méthode trouvée :\n       *Vous pouvez sauvegarder 1 méthode pour la recharger plus tard:\n       -Cliquer sur le bouton rouge 'sauvegarder' quand la méthode fonctionne,\n       -Lorsque vous dénombrerer le même type de boîtes, vous pourrez 'charger' (bouton vert) la méthode (Fichier xxx.pickle).                               ..Tuto suivant"
            self.ui.Suggestions_2.append(Sugg_Tuto2)
            self.ui.Suggestions_2.show()
        elif self.tuto==7:
            self.ui.Suggestions_2.hide()
            Sugg_Tuto="Tuto N°7 : Exercice \n     -Calibration Milieu,\n     -Contraste-->Max de contours,\n     -Résolution de paquets..?\n                                                                            -->Tuto suivant"
        elif self.tuto==8:
            self.ui.Suggestions_2.hide()
            Titre_Sugg_intro="A vous de jouer !"
            self.ui.Titre_Suggestions.clear()
            self.ui.Titre_Suggestions.append(Titre_Sugg_intro)
            self.Past()
            Sugg_Tuto="  * 1) Faîtes les défis Pickle : Résolvez les Tutos 9 et/ou 10, et envoyez moi vos Pickles (dfialaire@gmail.com)\n\n  * 2) Brancher votre Webcam.. et Dénombrez Instantanément vos boîtes de Pétri !\n  Ps : Si votre image Webcam est très fluctuante, cliquez sur Capture."
        elif self.tuto==9:
            self.ui.Suggestions_2.hide()
            Sugg_Tuto="Tuto N°9 :\n          Très belles colonies de Staphylococcus avec halo,\n               --> Envoyez moi votre Pickle résolu ! (dfialaire@gmail.com)"          
        elif self.tuto==10:
            self.ui.Suggestions_2.hide()
            Sugg_Tuto="Tuto N°9 :\n          Très jolie boîte de 2 types de colonies,\n               --> Envoyez moi vos 2 Pickles résolus : 1 pour chaque couleur !\n         (dfialaire@gmail.com)"            
        self.ui.Suggestions.append(Sugg_Tuto)

        
        
        self.new_Capt=0
        self.Pass_MewTut=1
        self.List_info_paquets=[] 
                ################
        self.ListeAirePaquet=[]
        self.ListeNbColPlus=[]
        self.NbColIsol=0
        self.Num_paquet=0
        self.Aire_paquet=0
        self.Aire_col_imp_elev=0
        self.Nb_col=0
        self.SomColPlus=0
        self.NbTotcol=0
        self.Ni=0
        self.SomeListeAirePaquet=0
        self.SommColTot=0
        #self.hauti=0
        ################
        list_titre=["calib3.jpg","calib1.jpg","Bleu2c.jpg","test5.jpg","test4.jpg","VRBL3.jpg","Staph1.jpg","Past.jpg","exo1.jpg","BleuViolet.jpg"]
        self.tuto=self.ui.horizontalSlider_Tutos.value()
        titre=list_titre[self.tuto-1]
        pil_img=Image.open(titre) # test4.jpg  # calib1.jpg# Bleu2.jpg # test3_pix1.jpg  # Staph1.jpg # VRBL3.jpg
        self.img = numpy.array(pil_img)
        if self.tuto!=8:
            self.img = cv2.cvtColor(self.img, cv2.COLOR_BGR2RGB)
        self.new_tuto=1
        #if self.tuto!=8:
        self.fonction_pe()
#################################################
       
#################################################
    def Tutos(self):
        self.ui.Suggestions.show()
        #self.ui.Suggestions_2.show()
        self.ui.Titre_Suggestions.show()
        self.ui.Suggestions.clear()
        self.ui.Titre_Suggestions.clear()
        self.ui.Titre_Suggestions.setFontFamily("Arial Black")
        self.ui.Titre_Suggestions.setStyleSheet("color: rgb(0, 0, 255);")
        self.ui.Titre_Suggestions.setFontPointSize(14)
        #self.ui.Titre_Suggestions.setTextColor("0000FF") 
        Titre_Sugg_intro="Suggestions :"
        self.ui.Titre_Suggestions.append(Titre_Sugg_intro)
        self.ui.Suggestions.setFontPointSize(14)
#
#        if self.tuto==1:
#            Sugg_Tuto="Tuto N°1 :\n\n "
#        elif self.tuto==2:
#            Sugg_Tuto="Tuto N°2 :\n\n "
#        self.ui.Suggestions.append(Sugg_Tuto)
        
        self.ui.radioButton_Capture.setEnabled(False)        
        if not self.timer.isActive():
            #print("not timer active dans tuto")
            #a=self.f
            self.timer.start(0)
            if self.new_tuto==0:  ## Passage intro à tuto : ok                
                self.New_fTutos()
            elif self.new_tuto==1: ## Passage tuto connecté à tuto checké ?? impossible
                #print("yadza1     ntuto=1")
                self.New_fTutos()
                #print("*************** yadza2     ntuto=1   suite pe")
                #print("*************** yadza2     ntuto=1   suite pe")
                self.fonction_pe()
            else:  #reste tuto=2 : donc passage webcam à tuto
                #a=self.f
                self.New_fTutos()
        else:
            #print("************ timer active dans tuto")
            #print("timer_stop=")
            self.timer.stop()
#################################################
    def Capture(self):
        #print("coucou1")
        if not self.timer.isActive():
            #a=self.f
            #print("coucou2")
            self.timer.start(0)
            if self.new_Capt==0:
                #print("coucou3")
                self.New_fCapt()
            elif self.new_Capt==1:
                #print("coucou7")
                self.fonction_pe()

        else:
            #print("timer_stop=")
            self.timer.stop()
################################################
    #########################
    def New_fCapt(self):
        #print("coucou5")
        self.Pass_MewTut=1
        self.List_info_paquets=[] 
                ################
        self.ListeAirePaquet=[]
        self.ListeNbColPlus=[]
        self.NbColIsol=0
        self.Num_paquet=0
        self.Aire_paquet=0
        self.Aire_col_imp_elev=0
        self.Nb_col=0
        self.SomColPlus=0
        self.NbTotcol=0
        self.Ni=0
        self.SomeListeAirePaquet=0
        self.SommColTot=0
        #self.hauti=0
        ################
        #list_titre=["calib3.jpg","calib1.jpg","Bleu2c.jpg","test5.jpg","test4.jpg","VRBL3.jpg","Staph1.jpg","exo1.jpg","BleuViolet.jpg","CaptWeb.jpg"]
        #self.tuto=self.ui.horizontalSlider_Tutos.value()
        

        self.capt=1
        #cam=cv2.VideoCapture(0)
        #ret,self.img=cam.read()
        self.cam.release()
        
        if self.new_Capt==0:
#            cam=cv2.VideoCapture(0)
#            ret,self.img=cam.read()
#            self.cam.release()
            self.new_Capt=1
        
            self.weballum=1
            name_format="CaptWeb.jpg"
            imageio.imwrite(name_format, self.SansTrait[:, :])
            pil_img=Image.open("CaptWeb.jpg") 
            self.img = numpy.array(pil_img)
        elif self.new_Capt==1:
            pil_img=Image.open("CaptWeb.jpg") 
            self.img = numpy.array(pil_img)            

        self.weballum=0

        self.webi=0

        #self.img = cv2.cvtColor(self.img, cv2.COLOR_BGR2RGB)

        self.fonction_pe()
#################################################
    def fonction_pe(self):
        #print("coucou6")
        self.Aire_col_imp=self.ui.lcdNumber.value()
        self.SansTrait=self.img
        #print ("* * * * * * * * *  lcd = ",self.Aire_col_imp)
        #Aire_col_imp=0
        self.diam_imp=round((self.Aire_col_imp/10)**(1/2.0627))
        table = np.array([ i * self.gamma for i in range (0,256)]).clip(0,255).astype('uint8')
#        if self.img.shape[2]==1:
#            modif=cv2.LUT(self.img, table)[:,:,np.newaxis]
#        else:
#            modif=cv2.LUT(self.img, table)  
##################################################
        
#        self.img=modif
        if self.zoom2==1:
            new_img=self.img[self.x2-160:self.x2+160,self.y2-240:self.y2+240]#self.x2-45:self.x2+35,self.y2-59:self.y2+61#self.x2-43:self.x2+37,self.y2-58:self.y2+62  #self.img[self.x2-20:self.x2+20,self.y2-30:self.y2+30]
            self.img = cv2.resize(new_img,(640,480))
            #img=cible(img,x,y)
            #cv2.imshow("En direct _ Video Webcam", img)
        else:
            ok=2
    ##############
        ## Formation du masque noir autour de la boîte
        if self.tuto !=8:
            if self.rayon>220:
                self.rayon=150
            mask_circle = np.zeros(self.img.shape[:2],np.uint8)
            cv2.circle(mask_circle,(320,240), self.rayon, 255, -1)
            self.img = cv2.bitwise_and(self.img, self.img, mask=mask_circle) 
        else:
            if self.rayon<321:
                self.rayon+=1
                mask_circle = np.zeros(self.img.shape[:2],np.uint8)
                cv2.circle(mask_circle,(320,240), self.rayon, 255, -1)
                self.img = cv2.bitwise_and(self.img, self.img, mask=mask_circle)
            else:
                mask_circle = np.zeros(self.img.shape[:2],np.uint8)
                cv2.circle(mask_circle,(320,240), self.rayon, 255, -1)
                self.img = cv2.bitwise_and(self.img, self.img, mask=mask_circle)                
    ##############
        xc=self.x2   ## self.y2
        #print("xc_cible",xc)
        yc=self.y2   ## self.x2
        #print("yc_cible",yc)
        xcmin=xc-3
        xcmax=xc+3
        ycmin=yc-3
        ycmax=yc+3

#        for x in range(xcmin,xcmax):
#            self.img[ycmin,x]=[255,255,255] #0,0,255
#        for x in range(xcmin,xcmax):
#            self.img[ycmax,x]=[255,255,255]
#    
#        for y in range(ycmin,ycmax):
#            self.img[y,xcmin]=[255,255,255]
#        for y in range(ycmin,ycmax):
#            self.img[y,xcmax]=[255,255,255]       
        #lower_test,upper_test=fonction_m(img,x2, y2,inverse)
        ##########"" fonction m
        x=self.x2
        y=self.y2
        p_unmin=255
        p_deuxmin=255
        p_troismin=255
        p_unmax=0
        p_deuxmax=0
        p_troismax=0
        #### Yop linéarisation de foction m qui ne devait pas toucher à img si linéaire avec fonction p !!
        copy_img=self.img
        if self.inverse==1:
            #print("inverse_l251=",self.inverse)
            self.img = (255-self.img)
        else:
            #print("inverse_l254=",self.inverse)
            ok=2
        image = cv2.cvtColor(self.img, cv2.COLOR_BGR2HSV)


        xpmin=x
        xpmax=x+6
        ypmin=y
        ypmax=y+6
        cible_img=image[xpmin:xpmax,ypmin:ypmax]
        #cible_img=self.img[xpmin:xpmax,ypmin:ypmax]
        for xp in range(xpmin,xpmax-1):
            for yp in range(ypmin,ypmax-1):
                p=self.img[xp,yp]
                Prep_pixel = np.uint8([[p]])
                hsv_pixel = cv2.cvtColor(Prep_pixel,cv2.COLOR_BGR2HSV)
                pi=hsv_pixel[0]
                p_un=pi[0][0]
                p_deux=pi[0][1]
                p_trois=pi[0][2]
                if p_un<p_unmin:
                    p_unmin=p_un
                else:
                    z=1
                if p_un>p_unmax:
                    p_unmax=p_un
                else:
                    z=1
                if p_deux<p_deuxmin:
                    p_deuxmin=p_deux
                else:
                    z=1
                if p_deux>p_deuxmax:
                    p_deuxmax=p_deux
                else:
                    z=1 
                if p_trois<p_troismin:
                    p_troismin=p_trois
                else:
                    z=1
                if p_trois>p_troismax:
                    p_troismax=p_trois
                else:
                    z=1 
        #lower_test=[p_unmin,25,25]
        #lower_test=[p_unmin,p_deuxmin,p_troismin] ## cool
        lower_test=[p_unmin-32,p_deuxmin,p_troismin]  ###
        #upper_test=[p_unmax,255,255]
        #upper_test=[p_unmax,p_deuxmax,p_troismax]  ## cool
        upper_test=[p_unmax+32,p_deuxmax,p_troismax]  ###

        self.img=copy_img

        ###########  fin fonction m
    ###################   Deb fonction p
        ### modif=adjust_brightness(img, gamma) ___ diam_imp
        table = np.array([ i*self.gamma for i in range (0,256)]).clip(0,255).astype('uint8')
        #image=self.img
        if self.img.shape[2]==1:
            modif=cv2.LUT(self.img, table)[:,:,np.newaxis]
        else:
            modif=cv2.LUT(self.img, table)  
##################################################
        self.img=modif
        hauteur, largeur = self.img.shape[:2]
        # sortie d'image avec contours
        self.image_contours = self.img.copy()
        # Détection des colonies 
        colors = ["colonies"]
        for color in colors:
            # copie de l'image originale
            image_to_process = self.img.copy()
            # initialisation du compteur
            counter[color] = 0
            # Dépôt des marges (GBR) de détection des couleurs dans un NumPy arrays
            if color == "colonies":               
                lower = np.array(lower_test)
                upper = np.array(upper_test)
            if self.inverse==1:
                image_to_process = (255-image_to_process)
            else:
                ok=2
            # Recherche des couleurs spécifiées dans les marges dans un masque
            image_mask2 = cv2.cvtColor(image_to_process, cv2.COLOR_BGR2HSV)

            image_mask = cv2.inRange(image_to_process, lower, upper)


            # application du masque
            image_res = cv2.bitwise_or(image_to_process, image_to_process, mask = image_mask)

     ##########"
            ## Transformation de l'image en nuance de gris et flouttage Gaussien
            image_gray = cv2.cvtColor(image_res, cv2.COLOR_BGR2GRAY)
            image_gray = cv2.GaussianBlur(image_gray, (5, 5), 0)


            # Détection des contours, et résolution des imperfections
            image_edged = cv2.Canny(image_gray, 50, 100)
            image_edged = cv2.dilate(image_edged, None, iterations=1)
            image_edged = cv2.erode(image_edged, None, iterations=1)

    #############"
            if self.mode == "isole":
                cnts, hierarchy = cv2.findContours(image_edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                cnts = cv2.findContours(image_edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            else:
                cnts, hierarchy = cv2.findContours(image_edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
                cnts = cv2.findContours(image_edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)     
                #cnts = cv2.findContours(image_edged.copy(), cv2.RETR_CCOMP, cv2.CHAIN_APPROX_NONE)
                ###cnts = cv2.findContours(image_edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

                #cnts_tot = cv2.findContours(image_edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE) ##
                #cnts_tour = cv2.findContours(image_edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                #cnts = cnts_tot - cnts_tour

            cnts = cnts[0] if len(cnts) == 2 else cnts[1]
        #####################################
            if self.mode=="tapis":
                if hierarchy is None:
                    ko=2
                else:
                    hierar = list(chain.from_iterable(hierarchy))
                    lenhierar=len(hierar)
                    listi=[]
                    for xc in range(0, lenhierar):
                        xcv=hierar[xc]
                        xcvb=hierar[xc][3]
                        if xcvb==-1:
                            listi.append(xc)
        ####
                    listi=sorted(listi, reverse=True)
                    #print(listi)
                    leny=len(listi)
                    for a in range(0,leny):
                        u=listi[a]
                        del hierar[u]
                        del cnts[u]
        #####################################
            Aires=[]
            compte=1
            #self.Aire_col_imp=int(10*(pow(self.diam_imp,2.0627)))  ##float
            self.Nb_sup_wh=0
            self.List_info_paquets=[]
            for c in cnts:
                #print("0 Grp : 499 :contourArea(c)=",cv2.contourArea(c),"self.w=",self.w,"self.wh=",self.wh)
                if cv2.contourArea(c) < self.w or cv2.contourArea(c)>self.wh:   ##1  #5
                    if cv2.contourArea(c)>self.wh:
                        #print("1er grp 502 :contourArea(c)=",cv2.contourArea(c),"self.w=",self.w,"self.wh=",self.wh )
                        aire_compt=cv2.contourArea(c)
                        infos=(compte,aire_compt)
                        compte+=1
                        self.List_info_paquets.append(infos)
                        self.Nb_sup_wh=self.Nb_sup_wh+1
                        #print("1er grp 508 : New   Nb_sup_wh=",self.Nb_sup_wh)
                    continue
                if cv2.contourArea(c)>self.Aire_col_imp:
                    #print("2ème grp 511 :contourArea(c)=",cv2.contourArea(c),"self.Aire_col_imp=",self.Aire_col_imp)
                    aire_compt=cv2.contourArea(c)
                    infos=(compte,aire_compt)
                    compte+=1
                    self.List_info_paquets.append(infos)
                    self.Nb_sup_wh=self.Nb_sup_wh+1
                    #print("2ème grp 517 : New   Nb_sup_wh=",self.Nb_sup_wh)
                #print("List_info_paquets =",self.List_info_paquets)
    ##############
                Aire=cv2.contourArea(c)
                Aires.append(Aire)
                # Création de la coqie convexe du contour
                hull = cv2.convexHull(c)
                if color == "colonies":
                    # Marquer le contour en vert
                    cv2.drawContours(self.image_contours,[hull],0,self.coul,1) #0,0,255 # 204,102,0
                counter[color] += 1
                # Décocher le commentaire ci-dessous pour écrire, sur l'image, les TAILLES de colonies détectées
                if self.affiche_Aire==1:
                    cv2.putText(self.image_contours, "{:.0f}".format(cv2.contourArea(c)), (int(hull[0][0][0]), int(hull[0][0][1])), cv2.FONT_HERSHEY_SIMPLEX, 0.65, (0, 0, 0), 2)
                else:
                    ko=1
            Len_Aires=len(Aires)
            if Len_Aires>0:
                self.Aire_Moy= int(statistics.mean(Aires) )
            else:
                self.Aire_Moy=0
            Aires=[]
        #cv2.imwrite("Capture_denombrement.jpg",image_contours)     ######
        self.image_contours = self.image_contours.astype (np.uint8)
    ###################   Fin fonction p  
        self.comptage=counter[color]
        if self.Nb_List!=10:
            self.List_max.append(self.comptage) #comptage de fonction p
            self.Nb_List+=1
        else:
            val=max(self.List_max)
            self.Comptage_max=val
            val_min=val-((20/10)*val)
            for elem in self.List_max:
                if elem<val_min:
                    self.List_max.remove(elem)
            valo=min(self.List_max)
            self.Comptage_min=valo
            self.Nb_List=0
            self.List_max=[]
        self.moyenne=(self.Comptage_min+self.Comptage_max)/2
        height, width, channel = self.img.shape
#        print(height, width, channel)
        step = channel * width
##########"
        xc=self.y2
        #print("xc_cible",xc)
        yc=self.x2
        #print("yc_cible",yc)
        #print()
        xcmin=xc-3
        xcmax=xc+3
        ycmin=yc-3
        ycmax=yc+3
        for x in range(xcmin,xcmax):
            self.image_contours[ycmin,x]=[255,0,0] #0,0,255
        for x in range(xcmin,xcmax):
            self.image_contours[ycmax,x]=[255,0,0]
    
        for y in range(ycmin,ycmax):
            self.image_contours[y,xcmin]=[255,0,0]
        for y in range(ycmin,ycmax):
            self.image_contours[y,xcmax]=[255,0,0]
##############
################            
 

 ################           
##############" 

        if self.trait==0:
            qImg = QImage(self.image_contours.data, width, height, step, QImage.Format_RGB888)
        else:
            qImg = QImage(self.SansTrait.data, width, height, step, QImage.Format_RGB888)
            
        self.ui.image_label.setPixmap(QPixmap.fromImage(qImg))
        

        
        Texte1="On compte : "
        Texte2=" colonies."
        texte2b=" colonie."
        if self.comptage<2:
            Texte=str(Texte1)+str(self.comptage)+str(texte2b)
        else:
            Texte=str(Texte1)+str(self.comptage)+str(Texte2)
            
        self.ui.label_7.setText(Texte)
        texte2="Min : "+str(self.Comptage_min)
        self.ui.label_8.setText(texte2)
        texte3="Max : "+str(self.Comptage_max)
        self.ui.label_9.setText(texte3)
        texte4="Moyenne : "+str(self.moyenne)
        self.ui.label_10.setText(texte4)
        texte5="x="+str(self.y2)
        self.ui.label_11.setText(texte5)
        texte6="y="+str(self.x2)
        self.ui.label_12.setText(texte6)

##################################################################
###############Texte pour travail de paquets #####################
##################################################################
        if self.Aire_col_imp==0:
            self.ui.textEdit.clear()
            self.ui.textEdit.setVisible(False)
            self.ui.label_13.setVisible(False)
            self.ui.label_14.setVisible(False)
            self.ui.label_15.setVisible(False)
            self.ui.label_16.setVisible(False)
            
        if self.Aire_col_imp>0:
            if self.Pass_MewTut==1:
                self.Pass_MewTut=0
                        ################
                self.ListeAirePaquet=[]
                self.ListeNbColPlus=[]
                self.NbColIsol=0
                self.Num_paquet=0
                self.Aire_paquet=0
                self.Aire_col_imp_elev=0
                self.Nb_col=0
                self.SomColPlus=0
                self.NbTotcol=0
                self.Ni=0
                self.SomeListeAirePaquet=0
                self.SommColTot=0
                self.ui.textEdit.clear()
                
                self.ui.textEdit.setVisible(True)
                self.ui.label_13.setVisible(True)
                self.ui.label_14.setVisible(True)
                self.ui.label_15.setVisible(True)
                self.ui.label_16.setVisible(True)
                self.Impression_paquet()
            
            if self.Ancien_Aire_col_imp != self.Aire_col_imp:
                
                self.ui.textEdit.clear()
                self.ListeAirePaquet=[]
                self.ListeNbColPlus=[]
                self.NbColIsol=0
                self.Num_paquet=0
                self.Aire_paquet=0
                self.Aire_col_imp_elev=0
                self.Nb_col=0
                self.SomColPlus=0
                self.NbTotcol=0
                self.Ni=0
                self.SomeListeAirePaquet=0
                self.SommColTot=0
                #self.hauti=0
                self.Impression_paquet()

                
                
    def  Impression_paquet(self):
        ################
        Texte23="Aire imposee ="+str(self.Aire_col_imp)
        self.ui.label_14.setText(Texte23)        
        self.NbColIsol=self.comptage-self.Nb_sup_wh
        #print("Nb_sup_wh ligne 690=",Nb_sup_wh )
        for paquet in range (0,self.Nb_sup_wh):
            #print("paquet=",paquet)
            #print("List_info_paquets=")
            #print(List_info_paquets)
            self.Num_paquet=self.List_info_paquets[paquet][0]
            #print("Num_paquet=",Num_paquet)
            self.Aire_paquet=self.List_info_paquets[paquet][1]
            #print("Aire_paquet=",Aire_paquet)   
            self.Aire_col_imp_elev=float(self.Aire_col_imp+((23/100)*self.Aire_col_imp))  ##float
            #print("Aire_col_imp_elev=",Aire_col_imp_elev)
            self.Nb_col=round(int(self.Aire_paquet/self.Aire_col_imp_elev),0)  ##float
            #Texte17="Paquet:"+str(Num_paquet)+", Nb.col="+str(Aire_paquet)
            Texte17="Paquet:"+str(self.Num_paquet)+", Nb.col="+str(self.Nb_col)
            self.ListeNbColPlus.append(self.Nb_col)
            #self.hauti=378+(12*self.Num_paquet)
            self.ListeAirePaquet.append(self.Aire_paquet)
            ###########cv2.putText(img, Texte17 ,(5,hauteur), font, 0.5, (0,0,255), 1);
            self.ui.textEdit.append(Texte17)
            self.Ancien_Aire_col_imp=self.Aire_col_imp
            #print("List_info_paquets=",List_info_paquets)
        ############
        #Texte23="Aire imposee ="+str(Aire_col_imp)
        #cv2.putText(img, Texte23 ,(5,180), font, 0.5, (0,0,255), 1);
        self.SomColPlus=int(sum(self.ListeNbColPlus))
        Texte21="Nb col. isolee:"+str(self.NbColIsol)
        self.ui.label_15.setText(Texte21)
        #print("NbColIsol ligne 717=",NbColIsol)
        #print(type(NbColIsol))
        #Texte20="Nb col. paquets en +:"+str(SomColPlus)+"."
        Texte20="Nb col. dans paquets en +:"+str(self.SomColPlus)
        self.ui.label_16.setText(Texte20)
        #print("Nb col. paquets en + ligne 721)",SomColPlus)
        self.NbTotcol=self.NbColIsol+self.SomColPlus  ##float
        self.Ni=self.NbTotcol
        Texte22="Nombre total de colonies: "+str(self.Ni)
        self.ui.label_13.setText(Texte22)
        #Texte22="Nombre total de colonies: "+str(NbTotcol)
        ###########cv2.putText(img, Texte20 ,(5,340), font, 0.5, (0,0,255), 1);
        ###########cv2.putText(img, Texte21 ,(5,315), font, 0.5, (0,0,255), 1);
        ###########cv2.putText(img, Texte22 ,(5,93), font, 0.5, (0,0,255), 1);
        #cv2.putText(img, "{:.0f}".format(Texte22) ,(5,93), font, 0.5, (0,0,255), 1);


        self.ListeNbColPlus=[]
        #self.Aire_col_imp=float(10*(pow(diam_imp,2.0627)))  ##float
        #print("diam_imp=",diam_imp)
        #print("Aire_col_imp de diamp_imp=",Aire_col_imp)
        self.SomeListeAirePaquet=sum(self.ListeAirePaquet)
        #SommColTot=round(float(sum(SomeListeAirePaquet/Aire_col_imp)),1)
        #if Aire_col_imp==0:
            #Aire_col_imp=1
        self.SommColTot=float((self.SomeListeAirePaquet/self.Aire_col_imp)*(75/100))  ##float
        #Texte18="Nb colonie(s) deduite(s) en + ="+str(SommColTot)
        #cv2.putText(img, Texte18 ,(5,410), font, 0.5, (255,255,255), 1);
        #############

        ##########
        self.Nb_sup_wh=0
        self.List_info_paquets=[]
###########################            
             
            
        #########################
    def viewCam2(self):
        #print("**********************  self.new_tuto= ",self.new_tuto)
        if self.ui.radioButton_Capture.isChecked() == True:
                self.New_fCapt()
                self.fonction_pe()            
        if self.ui.radioButton_Webcam.isChecked() == True:
            self.new_tuto=2
            #cam=cv2.VideoCapture(0)
            ret,self.img=self.cam.read()
            self.img = cv2.cvtColor(self.img, cv2.COLOR_BGR2RGB)
            self.fonction_pe()
        elif self.ui.radioButton_Tutos.isChecked() == True:
            if self.new_tuto==0:
                #print("Whattttttt !!!???")
                self.New_fTutos()
            elif self.new_tuto==1:
                #print("Bip Bap ** Bip Bap ** Bip Bap ** ")
                self.New_fTutos()
                self.fonction_pe()
                #print("Bip Bap ** Bip Bap ** Booooooooooo")
            else:
                self.New_fTutos()
#########################
    def viewCamTuto(self):
        self.fonction_pe()
#########################        

            
            
    # view camera
    def fond(self):

        img = Image.open("Img0.jpg")
        self.image_contours = numpy.array(img)
        height, width, channel = self.image_contours.shape
        step = channel * width
        qImg = QImage(self.image_contours.data, width, height, step, QImage.Format_RGB888)
        # show image in img_label
        self.ui.image_label.setPixmap(QPixmap.fromImage(qImg))            
####################################################
    def Past(self):
        
        img = Image.open("Past.jpg")
        self.image_contours = numpy.array(img)
        #self.img = cv2.cvtColor(self.img, cv2.COLOR_BGR2RGB)

        height, width, channel = self.image_contours.shape
        step = channel * width
        qImg = QImage(self.image_contours.data, width, height, step, QImage.Format_RGB888)
        # show image in img_label
        self.ui.image_label.setPixmap(QPixmap.fromImage(qImg)) 
#        self.x2=431
#        self.y2=513          
####################################################

#############################################
    def adjust_brightness(self,img, brightness_factor):
        table = np.array([ i*self.gamme for i in range (0,256)]).clip(0,255).astype('uint8')
        if img.shape[2]==1:
            return cv2.LUT(img, table)[:,:,np.newaxis]
        else:
            return cv2.LUT(img, table)  
##################################################

#############################################
if __name__ == "__main__":
        #########
    font = cv2.FONT_HERSHEY_SIMPLEX  # FONT_HERSHEY_SIMPLEX  # FONT_HERSHEY_PLAIN
    inverse=0
    #########################################
      # dictionnaire de comptage des colonies
    counter = {}
    ##################################
    gamma=1
    zoom=1
    x = 306
    y = 176
#    self.x2=274#240
#    self.y2=373#320
    p_unmin=255
    p_deuxmin=255
    p_troismin=255
    p_unmax=0
    p_deuxmax=0
    p_troismax=0
#    zoom2=0
    
#    Comptage_min=400
#    Comptage_max=0
    w=1
    wh=300
    # Nb_List=0
    Nb_List_max=10
    # List_max=[]
    
    Nb_List_min=0
    List_min=[]
    mode="isole"
    Nb_sup_wh=0
    List_info_paquets=[]
    ListeNbColPlus=[]
    cl=0
    cl_new=0
    fo=0
    fo_new=0
    weballum=0
    app = QApplication(sys.argv)
    w = MyForm()
    w.show()
    sys.exit(app.exec_())
    

###################################################

# %%
|pip freeze > requirements.txt
# Out:
#   File "<ipython-input-1-163e11fdf085>", line 1
#     |pip freeze > requirements.txt
#     ^
# SyntaxError: invalid syntax
